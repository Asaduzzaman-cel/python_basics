# %% [markdown]
# <a href="https://colab.research.google.com/github/Asaduzzaman-cel/python_basics/blob/main/first_p_n8n.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello world")
# Out:
# Hello world

# %%
print("My name is Md Asaduzzaman")
# Out:
# My name is Md Asaduzzaman

# %%
x=2
print(x)
# Out:
# 2

# %%
y="Bangladesh is a beautyful country"
print(y)
# Out:
# Bangladesh is a beautyful country

# %%
type(x)
# Out:
# int

# %%
type(y)
# Out:
# str

# %%
z=2.3
print(z)
# Out:
# 2.3

# %%
a=True
print(a)
# Out:
# True

# %%
print(a)
# Out:
# True

# %%
a=15
b=7
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a//b)
print(a%b)
# Out:
# 22
# 8
# 105
# 2.142857142857143
# 2
# 1

# %%
a="bangladesh"
c=" "
b="interactive cares"
print(a +c+ b)
# Out:
# bangladesh interactive cares

# %%
a="bangladesh"
b="interactive_cares"
print(a+" "+b)
# Out:
# bangladesh interactive_cares

# %%
obtained_merk=[80,81,78,90,76,65,71,69,85]
print(obtained_merk)
print(obtained_merk[0])
print(len(obtained_merk))
# Out:
# [80, 81, 78, 90, 76, 65, 71, 69, 85]
# 80
# 9

# %%
my_number= input()
# Out:
# lets do it

# %%
my_number
# Out:
# 'lets do it'

# %%
a=2.0
b=2
a==b
# Out:
# True

# %%
type(a)==type(b)
# Out:
# False

# %%
a=10
b=5
a>b
a>=b
# Out:
# False

# %%
a<=b
# Out:
# False

# %%
a=7
b=5
# a=a+b
#print(c)

# %%
a+=5
print(a)
# Out:
# 146

# %%
a*2
print(a)
# Out:
# 146

# %%
a/2
print(a)
# Out:
# 146
