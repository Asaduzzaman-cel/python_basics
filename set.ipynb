# %% [markdown]
# <a href="https://colab.research.google.com/github/Asaduzzaman-cel/python_basics/blob/main/set.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Set is unorder,unchangeable but you can add or remove item. you can not indexing also
# For unorder you can't get same result by every order.
#myset = {"apple","banana","cherry"}
#print(myset)
# Out:
# {'banana', 'apple', 'cherry'}

# %%
#print(myset)
# Out:
# {'banana', 'apple', 'cherry'}

# %%
#myset.add("orange")
#print(myset)
# Out:
# {'banana', 'orange', 'apple', 'cherry'}

# %%
myset.update(["orange","mango","grapes"])
print(myset)
# Out:
# {'grapes', 'banana', 'cherry', 'orange', 'apple', 'mango'}

# %%
myset1={"apple","banana","cherry"}
myset2={1,2,3}
myset1.update(myset2)
print(myset1)
# Out:
# {1, 2, 3, 'banana', 'apple', 'cherry'}

# %%
# loop in set
myset = {"apple","banana","cherry"}
for x in myset:
    print(x)
# Out:
# banana
# apple
# cherry

# %%
#there five rules to remove an items in set.1).remove 2).discard() 3) .pop() 4) .clae() 5)del
myset={"apple","banana","cherry"}
myset.remove("apple")
print(list)
# Out:
# ['apple', 'banana']

# %%
list={"apple","banana","cherry"}
list.pop() # pop() method ববহার করলে কোন আইটেম বাদ হবে ঠিক নাই তাই সাধারনত এই method বেশির ভাগ use হয় না
print(list)
# Out:
# ['apple', 'banana']

# %%
myset={"apple","banana","cherry"}
myset.discard("banana")
print(myset)
# Out:
# {'apple', 'cherry'}

# %%
myset={"apple","banana","cherry"} # when you use .clear method set will empty
myset.clear()
print(myset)
# Out:
# set()

# %%
myset={"apple","banana","cherry"}
del(myset)
#print(myset)# if you use del method set will permanently deleted.
