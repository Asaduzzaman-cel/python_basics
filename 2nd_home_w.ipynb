# %% [markdown]
# <a href="https://colab.research.google.com/github/Asaduzzaman-cel/python_basics/blob/main/2nd_home_w.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# #Arguments 1. The "Default" Calculator Create a function called calculate_area that takes length and width as arguments.
# # ●Set the width argument to have a default value of 1. ●The function should return the product of length and width.
# # ●Test it by calling it with both arguments, and then with only the length argument.
# def calculate_area(length, width=1):
#     return length * width
#     print(calculate_area(5, 3))
#     print(calculate_area(5))
# #2. The Flexible Sum (*args) Write a function called flexible_sum that accepts any number of positional arguments using *args.
# #●The function should loop through the arguments and return the total sum of all numbers passed to it.
# #●Example call: flexible_sum(5, 10, 15, 20) should return 50. (Reference: Variable length argument *args)
# def flexible_sum(*args):
#     total = 0
#     for num in args:
#         total += num
#     return total
# print(flexible_sum(5, 10, 15, 20))
# #3. Student Profile Builder (**kwargs) Create a function named build_profile that takes a mandatory argument name and any number of keyword arguments using
# #**kwargs. ●The function should return a dictionary (or print a formatted string) containing the name and all other key-value pairs provided.
# # ●Example call: build_profile("Sarah", age=25, city="New York", major="Physics"). (Reference: Keyword-arguments and **kwargs)
# def build_profile(name, **kwargs):
#     profile = {"name": name}
#     profile.update(kwargs)
#     return profile
# print(build_profile("Sarah", age=25, city="New York", major="Physics"))
# def build_profile(*name,**kwargs):
#   print("name:",name)
#   print("kwargs:",kwargs)
# build_profile("Sarah", age=25, city="New York", major="Physics")
# def build_profile(**kwargs):
#   print(kwargs)
# build_profile(name="Sarah", age=25, city="New York", major="Physics")
# Out:
# {'name': 'Sarah', 'age': 25, 'city': 'New York', 'major': 'Physics'}

# %%
#5. List Comprehension Logic Given the list numbers = [1, 4, 9, 16, 25, 36, 49, 64]:
# ●Use list comprehension to create a new list containing only the numbers from the original list that are even.
# numbers = [1, 4, 9, 16, 25, 36, 49, 64]
# even= [n for n in numbers if n % 2 == 0]
# print(even)
# numbers=[1,4,9,16,25,36,49,64] # same job two rules ‍
# new_list=[]
# for n in numbers:
#   if n %2==0:
#    new_list.append(n)
# print(new_list)
# Out:
# [4, 16, 36, 64]
# [4, 16, 36, 64]
