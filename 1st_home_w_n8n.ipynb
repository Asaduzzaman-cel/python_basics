# %% [markdown]
# <a href="https://colab.research.google.com/github/Asaduzzaman-cel/python_basics/blob/main/1st_home_w_n8n.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1. The "Chatbot" Greeter ●Concept: Input, String Formatting, Output. ●Task: Create a script that asks the user for their name,
#age, and favorite color. Then, print a formatted response like: "Hello [Name]! I see you are [Age] years old and love [Color]."
name=input( "what is your name")
age=input("How old are you")
color=input("what is your favorite color")
print(f"Hello {name}! I see you are {age} years old and love {color}.")
# Out:
# what is your name Md. Asaduzzaman
# How old are you 43
# what is your favorite color  puple
# Hello  Md. Asaduzzaman! I see you are  43 years old and love   puple.

# %%
# Data Cleaner Agent
#●Concept: String Methods (lower, strip, split).
#●Task: Given a "messy" string like " DaTa_ScIeNcE ", write a program to:
#1.Remove leading/trailing spaces.
#2.Convert it to lowercase.
#3.Replace underscores with spaces.
#Print the clean version: "data science"
data=" DaTa_ScIeNcE " #data নামে ভেরিয়েবলে একটি মেসি স্ট্রিং রাখা হলো। এতে শুরু ও শেষ—দুই জায়গাতেই স্পেস আছে।
data=data.strip() #strip() শুরুর এবং শেষের বাড়তি স্পেস সরিয়ে দেয়। ফলে " DaTa_ScIeNcE " → "DaTa_ScIeNcE"
data=data.lower() #পুরো স্ট্রিং ছোট হাতের অক্ষরে রূপান্তর হয়। "DaTa_ScIeNcE" → "data_science"
data=data.replace("_"," ") #আন্ডারস্কোর _ কে স্পেস " " দিয়ে বদলে দেয়। "data_science" → "data science"
print(data) #বাড়তি স্পেস,বড় হাত–ছোট হাত অক্ষর এলোমেলো,আন্ডারস্কোর / ড্যাশ / ভুল চিহ্ন,ভুল ফরম্যাট,অপ্রয়োজনীয় ক্যারেক্টার,বানান বা কেস মিক্সড,যেটা “clean”, “standard” ডেটা না
# Out:
# data science

# %%
data="DaTa_ScIeNcE"
data=data.lower()
data=data.strip()
data=data.split("_")
print(data)
# Out:
# ['data', 'science']

# %%
from ast import Return
# Rule-Based Number Classifier
# ●Concept: Conditional Logic (if/elif/else), Modulo Operator.
# ●Task: Ask the user for an integer. Write a logic flow that prints:
# ○"Even and Prime" (if applicable - Hint: 2 is the only even prime)
# ○"Even and Composite"
# ○"Odd and Prime"
# ○"Odd and Composite"
# Asking for integer input
n = int(input("Enter an integer: "))

# Function to check prime numbers
def is_prime(num):
    if num < 2:
        return False
    for i in range(2, int(num**0.5) + 1):
        if num % i == 0:
            return False
    return True

# Check even or odd
if n % 2 == 0:
    # It's even
    if is_prime(n):
        print("Even and Prime")
    else:
        print("Even and Composite")
else:
    # It's odd
    if is_prime(n):
        print("Odd and Prime")
    else:
        print("Odd and Composite")
# Out:
# Enter an integer: 8
# Even and Composite

# %%
#The "Guessing Game" Bot ●Concept: Random module, While loops, User Input. ●Task: Improve the guessing game example from class.
# The program should generate a random number between 1-50. The user keeps guessing until they get it right.
#The program must give hints: "Too High" or "Too Low" after every wrong guess. akhane amake ke korte bolche

# import random

# number = random.randint(1,50)

# while True:
#   guess=int(input("Guess a number (1-50):"))
#   if guess>number:
#     print("Too High!")
#   elif guess<number:
#     print("Too Low!")
#   else:
#     print("Correct! You got it!")

# %%
#●Concept: Iteration (For loop), String check (in).
#●Task:Take a sentence input from the user. Loop through the sentence and count how many vowels (a, e, i, o, u) exist in the text.
#Print the total count.
# sentence=input("Enter a sentence ")
# vowels="aeiouAEIOU"
# count=0
# for char in sentence:
#   if char in vowels:
#     count=count+1
# print(f"The number of vowels in the sentence is: {count}")
#   #  count+=1
#   #  print("Total vowels",count)
# Out:
# Enter a sentence I love Bangladesh
# The number of vowels in the sentence is: 6

# %%
#Level 3: Data Structures (Lists, Dictionaries, Sets) 6. Knowledge Base Lookup●Concept: Dictionaries (Key-Value pairs).
#●Task: Create a dictionary called ai_terms where keys are terms like "LLM", "Agent", "Python" and values are their definitions.
#Write a program that asks the user for a term and prints the definition. If the term doesn't exist, print "I don't know that term yet."
ai_terms={
    "LLM":"A Large Language Model that can understand and generate text. ",
    "Agent":"A system that can takes actions based on goals. ",
    "Python":"A popular programing language"
}
term=input("Enter a Trem: ")
if term in ai_terms:
  print(ai_terms[term])
else:
  print("I don't know that term yet")
# Out:
# Enter a Trem: KOI
# I don't know that term yet

# %%
#Duplicate Remover ●Concept: Sets vs. Lists, Type Conversion.
#●Task: Given a list of emails with duplicates: emails = ["a@test.com", "b@test.com", "a@test.com", "c@test.com"].
#Write a script to convert this list into a Set to remove duplicates, then convert it back to a List and print the unique sorted emails
#Conversion=
# list-(1)list হলো পাইথনের একটি odered collection.(২) এটা লিখতে [] ব্রাকেট ব্যবহার করতে হয়। (৩)এটা index দিয়ে access নেওয়া যায়। (৪) duplicate
# allow করে। (৫) এটা mutable. মান add/remove করা যায়
# ‍set- (1) set হলো পাইথনের একটি unodered collection.(2)এটা লিখতে {}ব্রাকেট ব্যবহার করতে হয়। (৩)এটা index দিয়ে ‍access নেওয়া যায় না।(৫)duplicate
# allow করে না। (5) mutable. মান add/remove করা যায়
fruits=["apple","banana","cherry","mango"]
print(type(fruits))
fruits_set=set(fruits)
print(type(fruits_set))
fruits_list=list(fruits_set)
print(type(fruits_list))
# Out:
# <class 'list'>
# <class 'set'>
# <class 'list'>
