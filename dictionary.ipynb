# %% [markdown]
# <a href="https://colab.research.google.com/github/Asaduzzaman-cel/python_basics/blob/main/dictionary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
motorcycle={
    "brand":"honda",
    "model":"trigger",
    "color":"black",
    "year":1920

}
print(motorcycle)
print(motorcycle["brand"])
print(motorcycle.keys())
print(motorcycle.values())
# Out:
# {'brand': 'honda', 'model': 'trigger', 'color': 'black', 'year': 1920}
# honda
# dict_keys(['brand', 'model', 'color', 'year'])
# dict_values(['honda', 'trigger', 'black', 1920])

# %%
print(motorcycle['model'])
# Out:
# trigger
